# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#RMSD
quercetin_rmsd1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_quercetin_run1.csv")
quercetin_rmsd2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_quercetin_run2.csv")
quercetin_rmsd3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_quercetin_run3.csv")
quercitrin_rmsd1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_quercitrin_run1.csv")
quercitrin_rmsd2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_quercitrin_run2.csv")
quercitrin_rmsd3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_quercitrin_run3.csv")
sesamin_rmsd1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_sesamin_run1.csv")
sesamin_rmsd2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_sesamin_run2.csv")
sesamin_rmsd3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rmsd/protein_rmsd_in_presence_of_sesamin_run3.csv")

#RG
quercetin_rg1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_quercetin_run1.csv")
quercetin_rg2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_quercetin_run2.csv")
quercetin_rg3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_quercetin_run3.csv")
quercitrin_rg1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_quercitrin_run1.csv")
quercitrin_rg2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_quercitrin_run2.csv")
quercitrin_rg3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_quercitrin_run3.csv")
sesamin_rg1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_sesamin_run1.csv")
sesamin_rg2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_sesamin_run2.csv")
sesamin_rg3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/rg/protein_rg_in_presence_of_sesamin_run3.csv")

#SASA
quercetin_sasa1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_quercetin_run1.csv")
quercetin_sasa2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_quercetin_run2.csv")
quercetin_sasa3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_quercetin_run3.csv")
quercitrin_sasa1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_quercitrin_run1.csv")
quercitrin_sasa2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_quercitrin_run2.csv")
quercitrin_sasa3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_quercitrin_run3.csv")
sesamin_sasa1 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_sesamin_run1.csv")
sesamin_sasa2 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_sesamin_run2.csv")
sesamin_sasa3 = pd.read_csv("/home/user1/Documents/GR_150ns/1st_review/combined_replicate_results/sasa/protein_sasa_in_presence_of_sesamin_run3.csv")

# %%
#RMSD
plt.figure(figsize=(16, 10))
sns.histplot(data=quercetin_rmsd1, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=quercetin_rmsd2, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=quercetin_rmsd3, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('RMSD (nm)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
plt.xlim(0,0.5)
sns.despine()
plt.savefig("quercetin_rmsd_histogram_combined_runs.png", dpi=300)
plt.show()

plt.figure(figsize=(16, 10))
sns.histplot(data=quercitrin_rmsd1, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=quercitrin_rmsd2, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=quercitrin_rmsd3, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('RMSD (nm)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
plt.xlim(0,0.5)
sns.despine()
plt.savefig("quercitrin_rmsd_histogram_combined_runs.png", dpi=300)
plt.show()

plt.figure(figsize=(16, 10))
sns.histplot(data=sesamin_rmsd1, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=sesamin_rmsd2, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=sesamin_rmsd3, x='RMSD', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('RMSD (nm)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
plt.xlim(0,0.5)
sns.despine()
plt.savefig("sesamin_rmsd_histogram_combined_runs.png", dpi=300)
plt.show()
# Out:
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#RG
plt.figure(figsize=(16, 10))
sns.histplot(data=quercetin_rg1, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=quercetin_rg2, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=quercetin_rg3, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('RG (nm)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
#plt.xlim(0,0.5)
sns.despine()
plt.savefig("quercetin_rg_histogram_combined_runs.png", dpi=300)
plt.show()

plt.figure(figsize=(16, 10))
sns.histplot(data=quercitrin_rg1, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=quercitrin_rg2, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=quercitrin_rg3, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('RG (nm)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
#plt.xlim(0,0.5)
sns.despine()
plt.savefig("quercitrin_rg_histogram_combined_runs.png", dpi=300)
plt.show()

plt.figure(figsize=(16, 10))
sns.histplot(data=sesamin_rg1, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=sesamin_rg2, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=sesamin_rg3, x='RG', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('RG (nm)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
#plt.xlim(0,0.5)
sns.despine()
plt.savefig("sesamin_rg_histogram_combined_runs.png", dpi=300)
plt.show()
# Out:
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#SASA
plt.figure(figsize=(16, 10))
sns.histplot(data=quercetin_sasa1, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=quercetin_sasa2, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=quercetin_sasa3, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('SASA (nm$^2$)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
#plt.xlim(0,0.5)
sns.despine()
plt.savefig("quercetin_sasa_histogram_combined_runs.png", dpi=300)
plt.show()

plt.figure(figsize=(16, 10))
sns.histplot(data=quercitrin_sasa1, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=quercitrin_sasa2, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=quercitrin_sasa3, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('SASA (nm$^2$)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
#plt.xlim(0,0.5)
sns.despine()
plt.savefig("quercitrin_sasa_histogram_combined_runs.png", dpi=300)
plt.show()

plt.figure(figsize=(16, 10))
sns.histplot(data=sesamin_sasa1, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="1st Run")
sns.histplot(data=sesamin_sasa2, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="2nd Run")
sns.histplot(data=sesamin_sasa3, x='SASA', kde=True, element='step', fill=True, alpha=0.2, 
             linewidth=2.0, label="3rd Run")
plt.xlabel('SASA (nm$^2$)', fontsize=20)
plt.ylabel('Distribution', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=20)
#plt.xlim(0,0.5)
sns.despine()
plt.savefig("sesamin_sasa_histogram_combined_runs.png", dpi=300)
plt.show()
# Out:
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/user1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
